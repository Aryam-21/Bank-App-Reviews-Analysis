# %%
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10016\3913539638.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query,conn)
#       review_id  bank_id          bank_name  \
# 1446       1451        3  Bank of Abyssinia
# 1447       1452        3  Bank of Abyssinia
# 1448       1453        3  Bank of Abyssinia
# 1449       1454        3  Bank of Abyssinia
# 1450       1455        3  Bank of Abyssinia
#
#                                             review_text  rating review_date  \
# 1446  the underrated app I've ever seen and ur banki...       1  2024-06-27
# 1447            It demands to disable developer option.       1  2024-06-27
# 1448  It's been two months now, I cannot do any tran...       1  2024-06-26
# 1449                                  Open Open service       5  2024-06-26
# 1450                                                NaN       1  2024-06-25
#
#      sentiment_label  sentiment_score             source
# 1446         Neutral           0.0000  Google Play Store
# 1447         Neutral           0.0000  Google Play Store
# 1448         Neutral          -0.4125  Google Play Store
# 1449         Neutral           0.0000  Google Play Store
# 1450         Neutral           0.0000  Google Play Store

# %%
# Out:
# {'Commercial Bank of Ethiopia': {'fast': np.int64(10),
#   'easy': np.int64(23),
#   'good_service': np.int64(4)},
#  'Dashen Bank': {'fast': np.int64(73),
#   'easy': np.int64(61),
#   'good_service': np.int64(9)},
#  'Bank of Abyssinia': {'fast': np.int64(19),
#   'easy': np.int64(15),
#   'good_service': np.int64(3)}}

# %%
# Out:
# {'Commercial Bank of Ethiopia': {'crash': np.int64(2),
#   'login': np.int64(7),
#   'slow': np.int64(1)},
#  'Dashen Bank': {'crash': np.int64(5),
#   'login': np.int64(5),
#   'slow': np.int64(20)},
#  'Bank of Abyssinia': {'crash': np.int64(27),
#   'login': np.int64(10),
#   'slow': np.int64(18)}}

# %%
# Out:
# {'Commercial Bank of Ethiopia': [],
#  'Dashen Bank': ['Optimize backend services to improve speed.'],
#  'Bank of Abyssinia': ['Improve app stability and crash reporting.',
#   'Enhance login reliability and reduce authentication errors.',
#   'Optimize backend services to improve speed.']}

# %%
# Out:
# sentiment_label              Negative  Neutral  Positive
# bank_name
# Bank of Abyssinia                  31      379        70
# Commercial Bank of Ethiopia        10      329       137
# Dashen Bank                        13      350       132

# %%
# Out:
# bank_name                    themes
# Bank of Abyssinia            Other                                                                                            274
#                              User Interface & Experience                                                                      142
#                              Transaction Performance                                                                           11
#                              Transaction Performance, User Interface & Experience                                              11
#                              Account Access Issues, User Interface & Experience                                                 8
#                              User Interface & Experience, Feature Requests                                                      8
#                              Feature Requests                                                                                   7
#                              Customer Support                                                                                   4
#                              Account Access Issues                                                                              3
#                              Transaction Performance, User Interface & Experience, Feature Requests                             3
#                              User Interface & Experience, Customer Support                                                      3
#                              Account Access Issues, Transaction Performance, User Interface & Experience, Customer Support      2
#                              User Interface & Experience, Customer Support, Feature Requests                                    2
#                              Account Access Issues, Transaction Performance, User Interface & Experience                        1
#                              Account Access Issues, Transaction Performance, User Interface & Experience, Feature Requests      1
#                              Account Access Issues, User Interface & Experience, Customer Support                               1
# Commercial Bank of Ethiopia  Other                                                                                            307
#                              User Interface & Experience                                                                      121
#                              Transaction Performance                                                                           11
#                              User Interface & Experience, Feature Requests                                                      9
#                              Feature Requests                                                                                   7
#                              Transaction Performance, User Interface & Experience                                               6
#                              Account Access Issues, User Interface & Experience                                                 4
#                              Account Access Issues                                                                              3
#                              User Interface & Experience, Customer Support                                                      3
#                              Account Access Issues, User Interface & Experience, Feature Requests                               2
#                              Customer Support                                                                                   2
#                              Account Access Issues, Feature Requests                                                            1
#                              Transaction Performance, Customer Support                                                          1
#                              Transaction Performance, User Interface & Experience, Customer Support                             1
# Dashen Bank                  Other                                                                                            232
#                              User Interface & Experience                                                                      168
#                              Feature Requests                                                                                  13
#                              User Interface & Experience, Feature Requests                                                     13
#                              Transaction Performance                                                                           12
#                              Transaction Performance, User Interface & Experience                                              10
#                              Account Access Issues, User Interface & Experience                                                 7
#                              Transaction Performance, User Interface & Experience, Feature Requests                             6
#                              User Interface & Experience, Customer Support, Feature Requests                                    6
#                              User Interface & Experience, Customer Support                                                      5
#                              Account Access Issues, Transaction Performance, User Interface & Experience                        4
#                              Account Access Issues, User Interface & Experience, Feature Requests                               4
#                              Customer Support                                                                                   4
#                              Account Access Issues                                                                              3
#                              Transaction Performance, Feature Requests                                                          3
#                              Customer Support, Feature Requests                                                                 2
#                              Account Access Issues, Transaction Performance                                                     1
#                              Account Access Issues, User Interface & Experience, Customer Support, Feature Requests             1
#                              Transaction Performance, User Interface & Experience, Customer Support                             1
#                              Transaction Performance, User Interface & Experience, Customer Support, Feature Requests           1
# Name: count, dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ## 1. Sentiment Distribution per Bank (Bar Plot)

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='bank_name', hue='sentiment_label')
plt.title("Sentiment Distribution by Bank")
plt.xlabel("Bank")
plt.ylabel("Number of Reviews")
plt.legend(title="Sentiment")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Rating Distribution per Bank (Box Plot)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=data, x='bank_name', y='rating')
plt.title("Rating Distribution by Bank")
plt.xlabel("Bank")
plt.ylabel("Rating")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Sentiment Trend Over Time (Line Chart)

# %%
data['review_date'] = pd.to_datetime(data['review_date'])

trend = (
    data.groupby([data['review_date'].dt.to_period('M'), 'bank_name'])['sentiment_score']
      .mean()
      .reset_index()
)

trend['review_date'] = trend['review_date'].dt.to_timestamp()

plt.figure(figsize=(12,5))
sns.lineplot(data=trend, x='review_date', y='sentiment_score', hue='bank_name')
plt.title("Monthly Sentiment Trend per Bank")
plt.xlabel("Month")
plt.ylabel("Average Sentiment Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Keyword Cloud per Bank (WordCloud)

# %%
banks = data['bank_name'].unique()

for bank in banks:
    text = " ".join(data[data['bank_name'] == bank]['review_text'].astype(str))
    
    wc = WordCloud(width=800, height=400, background_color="white").generate(text)

    plt.figure(figsize=(10,5))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title(f"Keyword Cloud — {bank}")
    plt.show()
